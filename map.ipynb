# %% [markdown]
# # Map1
# - Based on the number of Alumni, Hong Kong, Macau and Taiwan are not included in the total

# %%
import pandas as pd
from pyecharts.charts import Map
from pyecharts import options as opts

# Load the map data
file_path = 'region_dest.csv'
data = pd.read_csv(file_path)

# Standardize region names
data['Target region'] = data['Target region'].replace({
    'Mainland China': 'China',
    'Taiwan': 'Taiwan Region'
})

#delete 0
data = data[data['Count'] > 0]

# Filter data for Hong Kong and Singapore
hk_data = data[data['Source region'] == 'HKG']
sg_data = data[data['Source region'] == 'SGP']

# Prepare the data format for the map
hk_map_data = [list(z) for z in zip(hk_data['Target region'], hk_data['Count'])]
sg_map_data = [list(z) for z in zip(sg_data['Target region'], sg_data['Count'])]

# Visual mapping range
min_count = min(min(hk_data['Count']), min(sg_data['Count']))
max_count = max(max(hk_data['Count']), max(sg_data['Count']))

# Blue gradient color scheme
color_scheme = ["#e0f3f8", "#abd9e9", "#74add1", "#4575b4"]

# Build the world map
world_map = (
    Map()
    .add("Hong Kong Alumni", hk_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .add("Singapore Alumni", sg_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Global Alumni Distribution: Hong Kong and Singapore",
            subtitle="Based on number of alumni per destination region",
            pos_left="center"
        ),
        legend_opts=opts.LegendOpts(
            pos_top="5%",
            pos_right="5%",  # Move to top-right
            orient="vertical",
            textstyle_opts=opts.TextStyleOpts(font_size=12)
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_piecewise=False,
            min_=min_count,
            max_=max_count,
            range_text=["High", "Low"],
            pos_bottom="5%",
            pos_left="left",#Adjusting the Mapping Legend
            range_color=color_scheme
        ),
    )
)

# Render the result
world_map.render("global_alumni_world_map1.html")
world_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="505976540c39494c814b1ff781407fd3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_505976540c39494c814b1ff781407fd3 = echarts.init(
#                     document.getElementById('505976540c39494c814b1ff781407fd3'), 'white', {renderer: 'canvas'});
#                 var option_505976540c39494c814b1ff781407fd3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Hong Kong Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 14980
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 490
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 550
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 650
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 36160
#                 },
#                 {
#                     "name": "China",
#                     "value": 34450
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 2470
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 770
#                 },
#                 {
#                     "name": "France",
#                     "value": 12980
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 10390
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 350
#                 },
#                 {
#                     "name": "India",
#                     "value": 1900
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 430
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 500
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 4040
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 7020
#                 },
#                 {
#                     "name": "Macau",
#                     "value": 1280
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 1140
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 1510
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 5620
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 900
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 410
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 900
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 700
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 720
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 16320
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 4860
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 4460
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 3810
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 3170
#                 },
#                 {
#                     "name": "Taiwan Region",
#                     "value": 5960
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 1300
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 570
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 51500
#                 },
#                 {
#                     "name": "United States",
#                     "value": 165000
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": false,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "Singapore Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 11800
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 340
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 470
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 1900
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 1130
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 2240
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 340
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 30000
#                 },
#                 {
#                     "name": "China",
#                     "value": 12300
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 320
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 2400
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 1320
#                 },
#                 {
#                     "name": "France",
#                     "value": 19800
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 10900
#                 },
#                 {
#                     "name": "Hong Kong",
#                     "value": 14000
#                 },
#                 {
#                     "name": "India",
#                     "value": 12100
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 7100
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 370
#                 },
#                 {
#                     "name": "Italy",

# %% [markdown]
# # Map2
# - Based on the Logarithmic value of Alumni, Hong Kong, Macau and Taiwan are not included in the total

# %%
import numpy as np

# %%
# Add log-transformed column for visualization
data['LogCount'] = np.log1p(data['Count'])  # log(1 + x)

# %%
# Separate data
hk_data = data[data['Source region'] == 'HKG']
sg_data = data[data['Source region'] == 'SGP']

# Prepare log-scaled map data
hk_map_data = [list(z) for z in zip(hk_data['Target region'], hk_data['LogCount'])]
sg_map_data = [list(z) for z in zip(sg_data['Target region'], sg_data['LogCount'])]

# Define color gradient
color_scheme = ["#e0f3f8", "#abd9e9", "#74add1", "#4575b4"]

# Get range for visual map
min_log = min(min(hk_data['LogCount']), min(sg_data['LogCount']))
max_log = max(max(hk_data['LogCount']), max(sg_data['LogCount']))

# Build the map
world_map = (
    Map()
    .add("Hong Kong Alumni", hk_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .add("Singapore Alumni", sg_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Global Alumni Distribution: Hong Kong and Singapore (Log-Scaled)",
            subtitle="Use a logarithmic scale to balance the data",
            pos_left="center"
        ),
        legend_opts=opts.LegendOpts(
            pos_top="5%",
            pos_right="5%",
            orient="vertical"
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_piecewise=False,
            min_=min_log,
            max_=max_log,
            range_text=["High", "Low"],
            pos_bottom="5%",
            pos_left="left",
            range_color=color_scheme
        ),
    )
)

# Render the map
world_map.render("global_alumni_world_map_log1.html")
world_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="65033b4a89bb48d1a20ecacdf40dd4b3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_65033b4a89bb48d1a20ecacdf40dd4b3 = echarts.init(
#                     document.getElementById('65033b4a89bb48d1a20ecacdf40dd4b3'), 'white', {renderer: 'canvas'});
#                 var option_65033b4a89bb48d1a20ecacdf40dd4b3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Hong Kong Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 9.614538010517382
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 6.19644412779452
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 6.311734809152915
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 6.478509642208569
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 10.49573646899098
#                 },
#                 {
#                     "name": "China",
#                     "value": 10.44729330359671
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 7.81237820598861
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 6.647688373563329
#                 },
#                 {
#                     "name": "France",
#                     "value": 9.471242028892995
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 9.248695325852646
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 5.860786223465865
#                 },
#                 {
#                     "name": "India",
#                     "value": 7.550135342488429
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 6.066108090103747
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 6.2166061010848646
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 8.304247465078474
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 8.85666093701725
#                 },
#                 {
#                     "name": "Macau",
#                     "value": 7.155396301896734
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 7.039660349862076
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 7.32052696227274
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 8.634264863002075
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 6.803505257608338
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 6.018593214496234
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 6.803505257608338
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 6.55250788703459
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 6.580639137284949
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 9.700207901150696
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 8.488999457045455
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 8.403128235128264
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 8.24564690087386
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 8.061802274538348
#                 },
#                 {
#                     "name": "Taiwan Region",
#                     "value": 8.692993531219926
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 7.170888478512505
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 6.3473892096560105
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 10.849356503939038
#                 },
#                 {
#                     "name": "United States",
#                     "value": 12.013706813470414
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": false,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "Singapore Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 9.375939552625749
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 5.831882477283517
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 6.154858094016418
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 7.550135342488429
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 7.030857476116121
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 7.714677473800927
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 5.831882477283517
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 10.308985993422082
#                 },
#                 {
#                     "name": "China",
#                     "value": 9.417435838868785
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 5.771441123130016
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 7.783640596221253
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 7.186144304522325
#                 },
#                 {
#                     "name": "France",
#                     "value": 9.893487720457795

# %% [markdown]
# # Map3
# - Total Hong Kong, Macao and Taiwan to China

# %%
data_sum=data.copy()
data_sum['Target region'] = data_sum['Target region'].replace({'Mainland China': 'China',
                                                                     'Taiwan Region': 'China',
                                                                    'Hong kong': 'China',
                                                                    'Macau': 'China',})

# %%
# Add log-transformed column for visualization
data_sum['LogCount'] = np.log1p(data_sum['Count'])  # log(1 + x)

# %%
# Separate data
hk_data = data_sum[data_sum['Source region'] == 'HKG']
sg_data = data_sum[data_sum['Source region'] == 'SGP']

# Prepare log-scaled map data
hk_map_data = [list(z) for z in zip(hk_data['Target region'], hk_data['LogCount'])]
sg_map_data = [list(z) for z in zip(sg_data['Target region'], sg_data['LogCount'])]

# Define color gradient
color_scheme = ["#e0f3f8", "#abd9e9", "#74add1", "#4575b4"]

# Get range for visual map
min_log = min(min(hk_data['LogCount']), min(sg_data['LogCount']))
max_log = max(max(hk_data['LogCount']), max(sg_data['LogCount']))

# Build the map
world_map = (
    Map()
    .add("Hong Kong Alumni", hk_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .add("Singapore Alumni", sg_map_data, "world",
         label_opts=opts.LabelOpts(is_show=False),
         is_map_symbol_show=False)
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Global Alumni Distribution: Hong Kong and Singapore (Log-Scaled)",
            subtitle="Use a logarithmic scale to balance the data",
            pos_left="center"
        ),
        legend_opts=opts.LegendOpts(
            pos_top="5%",
            pos_right="5%",
            orient="vertical"
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_piecewise=False,
            min_=min_log,
            max_=max_log,
            range_text=["High", "Low"],
            pos_bottom="5%",
            pos_left="left",
            range_color=color_scheme
        ),
    )
)

# Render the map
world_map.render("global_alumni_world_map_log_sum of region.html")
world_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="49b6ecd705a6422f822b359bf8fc9a4e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_49b6ecd705a6422f822b359bf8fc9a4e = echarts.init(
#                     document.getElementById('49b6ecd705a6422f822b359bf8fc9a4e'), 'white', {renderer: 'canvas'});
#                 var option_49b6ecd705a6422f822b359bf8fc9a4e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Hong Kong Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 9.614538010517382
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 6.19644412779452
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 6.311734809152915
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 6.478509642208569
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 10.49573646899098
#                 },
#                 {
#                     "name": "China",
#                     "value": 10.44729330359671
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 7.81237820598861
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 6.647688373563329
#                 },
#                 {
#                     "name": "France",
#                     "value": 9.471242028892995
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 9.248695325852646
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 5.860786223465865
#                 },
#                 {
#                     "name": "India",
#                     "value": 7.550135342488429
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 6.066108090103747
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 6.2166061010848646
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 8.304247465078474
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 8.85666093701725
#                 },
#                 {
#                     "name": "China",
#                     "value": 7.155396301896734
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 7.039660349862076
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 7.32052696227274
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 8.634264863002075
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 6.803505257608338
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 6.018593214496234
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 6.803505257608338
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 6.55250788703459
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 6.580639137284949
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 9.700207901150696
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 8.488999457045455
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 8.403128235128264
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 8.24564690087386
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 8.061802274538348
#                 },
#                 {
#                     "name": "China",
#                     "value": 8.692993531219926
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 7.170888478512505
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 6.3473892096560105
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 10.849356503939038
#                 },
#                 {
#                     "name": "United States",
#                     "value": 12.013706813470414
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": false,
#             "emphasis": {}
#         },
#         {
#             "type": "map",
#             "name": "Singapore Alumni",
#             "label": {
#                 "show": false,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "map": "world",
#             "data": [
#                 {
#                     "name": "Australia",
#                     "value": 9.375939552625749
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 5.831882477283517
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 6.154858094016418
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 7.550135342488429
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 7.030857476116121
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 7.714677473800927
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 5.831882477283517
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 10.308985993422082
#                 },
#                 {
#                     "name": "China",
#                     "value": 9.417435838868785
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 5.771441123130016
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 7.783640596221253
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 7.186144304522325
#                 },
#                 {
#                     "name": "France",
#                     "value": 9.893487720457795
